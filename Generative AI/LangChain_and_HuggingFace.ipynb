# %% [markdown]
# # **Huggingface with Langchain**

# %% [markdown]
# # Libraries

# %%
pip install --upgrade langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 42.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-huggingface
# for api Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
##Environment secret keys
from google.colab import userdata
sec_key = userdata.get('HF_TOKEN')
print(sec_key)
# Out:
# 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

# %% [markdown]
# # **Huggingface Endpoint**

# %% [markdown]
# # Accessing Huggingface models with API

# %% [markdown]
# There are also tow ways to use this class. You can specify the model with the repo_id parameter. Those endpoints use the serverless API, which is particularly beeficial to people using pro accounts or enterprise hb, still, regular users can already have access to a fair amount of request by connecting with their HF token in the enviroment where they are executing the code.

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
##Environment secret keys
from google.colab import userdata
sec_key = userdata.get('HUGGINGFACEHUB_API_TOKEN')
print(sec_key)
# Out:
# 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

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN']=sec_key

# %%
repo_id = 'mistralai/Mistral-7B-Instruct-v0.2'
llm = HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.8, token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.2', model_kwargs={'max_length': 128, 'token': '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'}, model='mistralai/Mistral-7B-Instruct-v0.2', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.2', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.2', timeout=120)>)

# %%
llm.invoke('What is machine learning')
# Out:
# '? Machine learning is a subset of artificial intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine learning models are designed to identify patterns and make decisions based on data, and these models can be trained on large datasets to make increasingly accurate predictions or decisions.\n\nMachine learning models can be categorized into three main types: supervised learning, unsupervised learning, and reinforcement learning. In supervised learning, the model is trained on labeled data, meaning that the data includes both inputs and desired outputs. The model learns to map inputs to outputs based on this labeled data. In unsupervised learning, the model is given unlabeled data and must find patterns or relationships within the data on its own. In reinforcement learning, the model learns by interacting with its environment and receiving feedback in the form of rewards or punishments.\n\nMach
# ...

# %%
llm.invoke('what is geverative ai')
# Out:
# " and how does it differ from other types of ai?\n\nGenerative AI refers to a type of artificial intelligence that can create new content, such as text, images, or music, that didn't exist before. It does this by learning patterns from large datasets and then using those patterns to generate new content that resembles the data it was trained on but is not a copy.\n\nThe primary difference between generative AI and other types of AI, such as discriminative AI, lies in their focus. Discriminative AI is designed to identify patterns and make decisions based on existing data. It focuses on distinguishing between different classes or categories, such as identifying a dog in an image or recognizing speech.\n\nGenerative AI, on the other hand, goes beyond identification and generates new content. It can create new text, such as poetry or news articles, new images, or even new music compositions. It does this by learning the underlying patterns in the data and using those patterns to generat
# ...

# %% [markdown]
# New Model

# %%
repo_id = 'mistralai/Mistral-7B-Instruct-v0.3'
llm = HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.8, token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.3', model_kwargs={'max_length': 128, 'token': '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'}, model='mistralai/Mistral-7B-Instruct-v0.3', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>)

# %%
llm.invoke('What is deep learning')
# Out:
# '?\n\nDeep learning is a sub-field of machine learning that involves building artificial neural networks with many layers to learn and make decisions from complex data. These neural networks are designed to mimic the structure and function of the human brain, allowing them to automatically learn and improve from experience. Deep learning is used in a wide range of applications, including image and speech recognition, natural language processing, and autonomous vehicles.\n\nDeep learning algorithms are trained on large datasets, often containing millions or even billions of examples. The algorithms use a process called backpropagation to adjust the weights of the connections between the neurons in the network based on the error of the predictions made. This process allows the network to learn to recognize patterns and make accurate predictions on new, unseen data.\n\nDeep learning has achieved state-of-the-art performance in many areas, such as image classification, object detection, 
# ...

# %%
from langchain import LLMChain, PromptTemplate

question = 'Who won the Cricket world cup in the year 2011?'
template = """Question: {Question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables = ['question'])
print(prompt)
# Out:
# input_variables=['Question'] template="Question: {Question}\nAnswer: Let's think step by step."

# %%
llm_chain = LLMChain(llm=llm,prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# {'Question': 'Who won the Cricket world cup in the year 2011?', 'text': ' In 2011, the Cricket World Cup was won by India. The team captain of India at that time was Mahendra Singh Dhoni. Therefore, Mahendra Singh Dhoni was the captain of the team that won the Cricket World Cup in 2011.'}

# %% [markdown]
# # Other way to call the hugging face model
# If we need try huggingface pipeline model, then we need to download entire model in local environment.
# Disadvantages: Very big llm models, or multi models cannot download locally they are limited ram or rom.

# %% [markdown]
# # HugginFace Pipeline

# %% [markdown]
# Among transformers the pipeline is the most versatile tool in the Hugging Face toolbox. Langchain being designed primarily to address RAG and Agent use cases, the scope of the pipeline here is reduced to the following text-centric tasks, 'text-generation', 'text2text-generation','summarization','translation'.Models can be loaded directly with the from_model_id method

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id = "gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline('text-generation',model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7babe3511990>)

# %%
hf.invoke('what is machine learning')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'what is machine learning and what can be done with its capabilities?)\n\nSets the parameters of the computation. One of the advantages of "big data" is it\'s open-source and it can be used with Python but there are few implementations yet.\n\nAn alternative to machine learning is the idea of "co-model". That is, computer generated models become general-purpose, efficient algorithms for solving problems such as data sets.\n\nA recent example is the famous Hadoop program named Python.'

# %% [markdown]
# # Use Hugging Face pipelines with GPU

# %%
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id = 'gpt2',
    task = 'text-generation',
    device = 0,
    pipeline_kwargs = {'max_new_tokens':100},
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
from langchain_core.prompts import PromptTemplate
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain=prompt|gpu_llm

# %%
question = 'What is artifical Intelligence'
chain.invoke({'question':question})
# Out:
# "Question: What is artifical Intelligence\nAnswer: Let's think step by step. Imagine a world where AI can see human speech; for example, in order to use its AI to make a decision based on a sentence or speech, it would automatically select words from a database called humanSpatialReport, and its output will be what would normally be used for the words to be judged.\nWhen it sees a sentence it is immediately conscious whether or not it fits either the human or AI criteria and its decisions can be made based on those criteria. If it is looking up a specific"
